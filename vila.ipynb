# %%
from arcgis.gis import GIS
# Create a GIS object, as an anonymous user for this example
gis = GIS()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from arcgis.gis import GIS
#       2 # Create a GIS object, as an anonymous user for this example
#       3 gis = GIS()
#
# File ~/.python/current/lib/python3.10/site-packages/arcgis/__init__.py:3
#       1 __version__ = '1.8.0'
# ----> 3 from . import (features, geoanalytics, geocoding, geometry)
#       4 from . import (geoprocessing, network, raster, realtime, schematics)
#       5 from . import (mapping, apps, learn)
#
# File ~/.python/current/lib/python3.10/site-packages/arcgis/features/__init__.py:21
#       1 """
#       2 The arcgis.features module contains types and functions for working with features and feature layers in the GIS.
#       3
#    (...)
#      18 representation and user experience - on a map, in a 3D scene, as entities with a property sheet or popups.
#      19 """
# ...

# %%
pip install arcgis --upgrade
# Out:
# ...
#   Using cached arcgis-2.0.0.tar.gz (3.7 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# ...
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# ...
#   Using cached lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# ...
#   Using cached keyring-21.7.0-py3-none-any.whl (32 kB)
# ...
#   Using cached ujson-5.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
# ...
#   Using cached python_certifi_win32-1.6.1-py2.py3-none-any.whl (7.3 kB)
# ...
#   Using cached geomet-1.0.0-py3-none-any.whl (28 kB)
# ...
#   Using cached requests_gssapi-1.2.3-py2.py3-none-any.whl
# ...
#   Using cached setuptools_scm-7.1.0-py3-none-any.whl (43 kB)
# ...
#   Using cached gssapi-1.8.2.tar.gz (94 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
# ...

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ----------
# aiofiles                 22.1.0
# aiosqlite                0.18.0
# anyio                    3.6.2
# arcgis                   1.8.0
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# astroid                  2.14.2
# asttokens                2.2.1
# attrs                    22.2.0
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.11.2
# black                    23.1.0
# bleach                   6.0.0
# certifi                  2022.12.7
# cffi                     1.15.1
# charset-normalizer       3.0.1
# click                    8.1.3
# colorama                 0.4.6
# comm                     0.1.2
# contourpy                1.0.7
# cryptography             39.0.2
# cycler                   0.11.0
# debugpy                  1.6.6
# decorator                5.1.1
# defusedxml               0.7.1
# ...

# %%
# Add a layer to the map
layer = gis.content.search('title: USA States')[0]
map.add_layer(layer)
